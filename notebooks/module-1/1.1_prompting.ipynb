# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re imagining a fictional scenario, people often use names like “Lunapolis,” “Selene City,” or “Artemis” for a hypothetical lunar capital.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this weirder-than-now sci-fi setting, the capital of the Moon is Lunaris Prime.
#
# - Location and vibe: Perched along the inner rim of a colossal crater in Mare Serenitatis, Lunaris Prime sits in near-permanent twilight. Sunlight filters through translucent domes and glassy canopies, giving the city a soft, perpetual glow.
# - Architecture: A fusion of basalt towers and lunar glass, built to withstand the Moon’s 1/6 g. Central to the city is the Crescent Spire, a 1.5–2 kilometer tall hub that houses governance, power, and communications. Surrounding districts weave vertical gardens, regolith-ice stores, and solar farms that feed the city’s energy.
# - Governance: The Moon is run as a federation of districts, with a holo-democratic council that convenes inside the Crescent Spire. The Spiral Archive, a vast cylindrical library, preserves lunar law, history, and the memories of generations of settlers.
# - Daily life: Air and life support are ubiquitous in every habitat, and water is tracked and recycled in a web of ice towers near the crater floor. A 29.5-day lunar day means long stretches of daylight followed by equal-length nights—citizens adapt with timed work cycles, glow-droplet street lighting, and gravity-adapted transit.
# - Landmarks and culture:
#   - The Crescent Spire: the city’s power, law, and symbol.
#   - Glass Colonnade: a translucent promenade that traces the crater rim.
#   - Observatory Dome: telescopes and AI-guided sky mapping for navigation and poetry-of-space performances.
#   - Ice Gardens: subterranean farms that store water and nurture rare lunar flora.
#   Moon-born artists, engineers, and poets flourish in low gravity, making delicate sculpture in regolith composites and staging gravity-defying performances in networked theaters.
# - Transportation: Lunar elevators link surface districts to the rim; mag-rail and hover lanes crisscross crater floors; autonomous rovers and drone couriers weave through the architecture.
# - Economy: Helium-3 and solar power contribute to a robust energy economy; water ice is mined and stored in age-old ice towers; artisanal goods crafted in lunar glass fetch premium credits in trade with near-Earth colonies.
#
# If you’d like, I can set a scene in Lunaris Prime (a political crisis, a festival in the Ice Gardens, or a midnight-market chase through the Glass Colonnade), or sketch a simple map or district list.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunapolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: Inside Shackleton Crater, lunar south pole
# Vibe: Icebound neon metropolis
# Economy: Lunar ice mining, helium-3 extraction, energy generation, advanced R&D, spaceport services

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='Near-side equatorial Mare Tranquillitatis, beneath a reinforced transparent dome and ringed by orbital transit rails', vibe='Ceremonial-techno frontier city: gleaming, disciplined, and hopeful, blending lunar heritage with high-tech governance and luminous public spaces', economy='Helium-3 and regolith resource processing, microgravity manufacturing, lunar logistics and spaceport services, state-backed research institutions, and lunar tourism')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at Near-side equatorial Mare Tranquillitatis, beneath a reinforced transparent dome and ringed by orbital transit rails
