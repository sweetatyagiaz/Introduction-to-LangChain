# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='It’s none. The Moon isn’t a country or government, so it has no capital.\n\nIf you meant something else: \n- If you’re asking about capitalization of the word, the capital letter is "M" (Moon). \n- If you had a fictional universe in mind, tell me which one.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 584, 'prompt_tokens': 13, 'total_tokens': 597, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EKKhh3iKrNaHUZkci4BC9vQO1j9fK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a06bca-dec3-7a21-9f82-4d1fa78525f4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 584, 'total_tokens': 597, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
print(response.content)
# Out:
# It’s none. The Moon isn’t a country or government, so it has no capital.
#
# If you meant something else:
# - If you’re asking about capitalization of the word, the capital letter is "M" (Moon).
# - If you had a fictional universe in mind, tell me which one.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-EKKhh3iKrNaHUZkci4BC9vQO1j9fK',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 584,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0,
#                                                'text_tokens': None},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cache_write_tokens': None,
#                                            'cached_tokens': 0,
#                                            'image_tokens': None,
#                                            'text_tokens': None},
#                  'total_tokens': 597}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or capital. It’s a natural satellite of Earth. If you’re asking about a fictional universe, tell me the work and I can tell you what capital they use there.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, no permanent residents, and no sovereign nations. Under the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body.\n\nHowever, in science fiction, the Moon is often given fictional capitals:\n\n*   **"Artemis"** (from Andy Weir’s novel *Artemis*) is the name of the first and only city on the Moon.\n*   In various other sci-fi universes, moon colonies are often governed by Earth-based entities or independent corporate hubs, but none of these represent a real-world capital. \n\nFor now, the Moon remains an international common area dedicated to scientific exploration.', 'extras': {'signature': 'EnEKbwERTTIPmKYDjG+BqGHoEb29lPXECTkuCTaPRsBf9qpJyWbMWM2KoBKfpDDKd64Gte5pC3sKYqnY4cnz3/6YtY5xTPNlFDokkuQfRGNOwTJQS1ssbZYOrkrb4WJTbwZ7Qe8ucNLDTOD0kY+EUr99OQ=='}}]

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='9f866475-0823-43d4-8cd9-e6a60ef32aa9'),
#               AIMessage(content='There isn’t one. The Moon has no government or official settlements, so it has no capital. In fiction, authors sometimes name a lunar capital (e.g., Luna City or Selene), but nothing official exists in reality.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 503, 'prompt_tokens': 13, 'total_tokens': 516, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EKKn8zMcpnPmBMQkEDOPloYHKkVrg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a06bd0-0277-7f83-a350-f1731f543884-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 503, 'total_tokens': 516, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or official settlements, so it has no capital. In fiction, authors sometimes name a lunar capital (e.g., Luna City or Selene), but nothing official exists in reality.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='bf0127ec-9ef2-4f6e-9392-8b40baa62a61'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='f82d5d61-48b7-44f8-9aaa-0ed3bd9ba59e', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='d3db3852-9873-4cbc-abe0-cde33fb0eb82'),
#               AIMessage(content='Just to note: there isn’t a real capital on the Moon. Luna City would be a fictional concept, but I can sketch a vivid world where it’s the lunar capital.\n\nA plausible fictional Luna City (the Moon’s capital)\n- Location and layout\n  - Situated near the equator for easy Earth connection, with a southern-hemisphere foothold near water-ice deposits to support life support and fuel.\n  - Built inside a large crater ring or a cluster of linked lava tubes to provide natural shielding from radiation and micrometeoroids.\n  - Core districts ring a central civic plaza, with surrounding sectors dedicated to governance, science, industry, and culture.\n\n- Government and society\n  - Luna City serves as the seat of a lunar-wide government: a Municipal Council elected by residents from settlements across the Moon, plus an Earth liaison council for interplanetary coordination.\n  - Autonomy with Earth oversight for defense, space policy, and major infrastructure funding.\n  - Legal framework emphasizes resource rights, environmental stewardship of ice deposits, and open data sharing for scientific missions.\n\n- Districts and features\n  - Civic Core: City hall, archives, university campus, laboratories, and a grand observatory with lunar telescopes.\n  - Hydroponics Arcology: Vertical farms, oxygen production, and food distribution hubs.\n  - Research Quarter: Cryo-labs, cryo-synthesis facilities, ISRU (in-situ resource utilization) R&D, and planetary defense simulations.\n  - Market Basin: Trade, housing, clinics, and cultural centers; markets feature lunar crafts and Earth-imported goods.\n  - Culture and Arts Quarter: Museums, theaters, galleries, and venues for eclipse festivals and lunar concerts.\n  - Port and Transit: Spaceport, cargo halls, tube-tunnels and maglev lines linking with multiple landing pads and orbital transfer stations.\n\n- Infrastructure and daily life\n  - Domed habitats with layered radiation shielding, water recycling, and robust life-support systems.\n  - Solar arrays on the sunlit limb and large energy storage facilities to balance the lunar day-night cycle.\n  - Water ice mined from shadowed craters, processed into drinking water and oxygen, with excess used for fuel synthesis.\n  - Transportation includes pressurized transit tubes, lunar rovers, and a light-rail network linking districts.\n\n- Economy\n  - Core industries: ISRU technology, lunar mining support, life-support systems, and R&D in closed-loop ecology.\n  - Services: education, tourism (tours of the city and crater sites), medical research, and communications satellite servicing.\n  - International partnerships and private kolonies supply the city with talent and resources.\n\n- Culture and daily life\n  - A cosmopolitan culture blending Earth heritage with lunar traditions—think festivals celebrating eclipses, the “Daylight Market” in the Market Basin, and lunar art that references Earth seen from space.\n  - Education emphasizes STEM, space medicine, and lunar archaeology; citizens often participate in citizen science projects.\n  - Sports and recreation revolve around low-gravity activities, with venues for zero-g sports, gravity-friendly parks, and observatories.\n\n- Challenges and resilience\n  - Radiation protection, micrometeoroid shielding, and dust management are constant concerns.\n  - Dependence on Earth for certain supplies means robust redundancy and rapid-response logistics are essential.\n  - Environmental stewardship of ice deposits to ensure sustainable water and fuel sources.\n\nSample vignette\n- A typical morning in Luna City: a student walks through the glass-domed Civic Core toward the university, passing holographic plaques detailing the city’s governance milestones. In the Hydroponics Arcology, workers monitor nutrient streams while drones shuttle kibbled crops to a local market. At the Spaceport, a crew boards a transfer shuttle to survey a nearby crater site, while an eclipse festiv ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City isn’t a real place on Earth, but it’s a great seed for a detailed, lived-in setting. Here’s a cohesive, ready-to-use concept you can drop into a story, game, or worldbuilding project. I’ll describe Luna City as the capital of a lunar polity in the near future.
#
# Core concept
# - Name: Luna City
# - Role: Capital of the Moon (seat of government for the lunar nation/union, and a hub for trade, science, culture, and governance)
# - Timeframe: Roughly mid-22nd century onward, in a mature Earth–Moon political and economic system
# - Location: Shackleton Crater rim, lunar south pole vicinity. The rim basks in nearly constant sunlight for long stretches, while nearby crater floors hold water ice and volatiles. The site combines solar power potential with access to liquid water resources, plus a defensible, shielded habitat cluster.
#
# Government and politics
# - Polity: A federated lunar nation, often referred to as the Lunarian Confederation (or Lunaria, depending on your flavor). Earth governments are still involved in space governance, but Luna City governs lunar affairs with a high degree of autonomy.
# - Parliament: The Lunar Assembly, a representative body drawn from districts across lunar settlements. It passes laws on resource management, immigration, science funding, and infrastructure.
# - Executive: The Governor-General or Prime Overseer, supported by a Cabinet of Ministers for Security, Science, Industry, Culture, and Education.
# - Law and justice: The Lunar Court handles civil and criminal matters. A constitutional charter guarantees freedoms of science, assembly, and trade, with special protections for residents in off-Earth habitats.
# - Currency and economy: A digital, universally accepted lunar-credit system (the “Lumen”) backed by Earth–Moon financial mechanisms and the wealth of the mining, research, and manufacturing sectors.
#
# City layout and districts
# - Central Crown Dome: The political heart. The government buildings, Supreme Court, central council chamber, press/briefing centers, and the main civic plaza (Oath Plaza) sit under a vast glassy dome that doubles as a solar collector.
# - Arcology Ring: A series of stacked, vertical megastructures that house housing, schools, clinics, and small businesses. Each arcology is climate-controlled and uses mass-optimized shielding to reduce radiation exposure while preserving a comfortable living environment.
# - The Beacon Spine: A tall, multi-use tower that houses communications, weather and radiation monitoring, and a public observatory. It anchors the city visually and physically.
# - Ice Belt District: The industrial heart, housing water-ice processing, fuel production, and volatile extraction facilities. The district is designed to keep heavy work in shielded, maintenance-robotic spaces to protect residents.
# - Research Quarter: Universities, think tanks, particle labs, life-science facilities, and tech incubators. It’s a collaborative zone with Earth partners and visiting scholars.
# - Greenhouse Crescent: Large hydroponic farms, vertical forests, and urban agriculture to supply food and oxygen, plus research on closed-loop biosystems.
# - Manufacturing Belt: 3D printing hubs, fabrication labs, materials processing (basalt, regolith composites), and small-scale ship components.
# - Cultural Quarter: Museums, theaters, galleries, music venues, lunar heritage centers, and celebratory spaces for holidays and science outreach.
# - Lunar Medical Complex: Hospitals, emergency clinics, telepresence nodes to Earth-based specialists, and a research hospital for lunar-specific health needs.
# - Orbital Gate and Port: An accompanying spaceport hub serving arrivals from Earth and orbital stations, with transit to Earth and lunar surface via elevators, maglev, and air-lift systems.
# - Residential Clusters: Family and student housing coordinated with schools, clinics, and community centers; neighborhoods are color-coded by district for easy navigation.
#
# Architecture and technology
# - Design language: A blend of utilitarian lunar pragmatism and elegant, multi-layered domes. Exposed interiors emphasize light, openness, and clean lines to counter the claustrophobia of space life.
# - Materials: Local basalt-ash composites, regolith-derived glass composites, and lightweight alloys. Shielding uses regolith blankets, water, and hydrogen-rich materials to reduce radiation exposure.
# - Climate and life support: Fully pressurized domes with closed-loop air and water recycling. Hydroponics and algae systems produce oxygen and food; stress-minimizing lighting mimics Earth day-night cycles.
# - Power: A hybrid system of solar arrays on elevated rings and sunlit plains, plus compact, safe nuclear or advanced fission microreactors for night cycles and high-demand processes. Battery storage buffers supply during eclipse periods.
# - Mobility: Tethered elevator links to nearby relay stations, electric hover-vehicles for intra-city travel, and autonomous service bots for logistics. Interior corridors use magnetic or low-friction rails to reduce fatigue in low gravity.
#
# Life in Luna City
# - Everyday work: Researchers, engineers, miners, medics, educators, and service workers—many split time between Luna City, nearby industrial sites, and Earth.
# - Education: Schools emphasize lunar science, engineering, and ethics of space habitation. Universities partner with Earth institutions for joint programs and exchanges.
# - Culture and arts: A vibrant, cosmopolitan culture blending Earth traditions with lunar storytelling: art installations built with regolith, performances in low-gravity, and public science festivals that celebrate water, ice, and exploration.
# - Public life: Public plazas are designed for airless or near-airless days; people socialize in protected spaces with artificial skylights and virtual-reality overlays for travel experiences back on Earth.
# - Health and psychology: Mental health services are standard; community centers support families and long-term residents with education, mindfulness spaces, and outdoor feeling-light experiences simulated in domes.
#
# Economy and sectors
# - Core industries: Water and volatile extraction, life-support systems, space manufacturing, and scientific research. Space tourism from Earth and orbital stations is growing.
# - Trade: Earth-based partners supply advanced materials, electronics, and cultural goods; Luna City exports water, isotopes for research, and manufactured lunar components.
# - Innovation: Startups focus on habitat tech, radiation shielding, bioreactors, autonomous mining, and in-situ resource utilization (ISRU) improvements.
#
# Notable institutions and people
# - The Lunar Assembly: Elected representatives debating policy and budgets.
# - The Office of the Overseer: The executive leadership team that implements Assembly laws and oversees day-to-day operations.
# - The Great Archive: A vast library of lunar history, scientific data, and interstellar exploration records.
# - The Lighthouse Observatory: Public and research-grade telescope facility; a symbol of lunar science and a tourist draw.
# - Notable character archetypes: The Chief Scientist who guides ISRU breakthroughs; the Security Chief who balances freedom with safety; a veteran astronaut-turned-politician; a young engineer who drives a breakthrough in ISRU.
#
# History and timeline (focused arc)
# - 2050s–2060s: Permanent lunar outposts grow; Earth–Moon governance discussions begin.
# - 2080s: Shackleton-like sites become viable for year-round operations due to solar access and water ice discoveries.
# - 2100: Luna City emerges as a political center as the Moon attains a stable degree of self-governance and economic autonomy.
# - 2120s–2130s: The Lunarian Confederation solidifies, with Luna City as its symbolic and administrative capital, expanding education, cybersecurity, and cultural institutions.
# - 2140s onward: Continued expansion of ISRU, robotics, and autonomous manufacturing; Luna City becomes a hub of interplanetary diplomacy and commerce.
#
# Key conflicts and themes you can explore
# - Resource governance: Water ice and volatile extraction compete with industrial demands and Earth claims.
# - Independence vs. Earth oversight: Balancing autonomy with Earth-based support and trade agreements.
# - Social dynamics: A diverse population of settlers, scientists, engineers, and creators argues over privacy, surveillance, and the right to self-determination in a tightly controlled habitat.
# - Environmental resilience: Dust management, radiation shielding, and habitat maintenance in a harsh, vacuum environment.
# - Identity: What it means to be lunar-born versus Earth-born in a city that is a national capital.
#
# Alternate flavors you can use
# - Corporate Luna City: Run by a powerful consortium (the “Luminex Consortium”) with a strong security apparatus, a privatized police force, and a city-state role for corporate governance. Moral ambiguities, private armies, and profit-driven decisions shape the daily life.
# - Democratic resurgence Luna City: A more egalitarian, Earth-like democratic style of governance with robust public programs, frequent referendums, and strong civil society organizations.
# - Mythic lunar capital: Elements of lunar folklore, ritual celebrations around water-ice harvesting, and sacred sites integrated into civic life—blending science with lunar spirituality.
#
# If you’d like, I can tailor this concept to your needs:
# - A shorter world bible for a novel or RPG.
# - A map layout with grid coordinates and district sizes.
# - A day-in-the-life vignette to spark scenes.
# - A variant focusing on a specific department (e.g., science, diplomacy, or security).
#
# Would you like me to customize Luna City for a particular genre (hard sci-fi, space opera, dystopian, etc.), or flesh out a particular district or institution in more detail?
