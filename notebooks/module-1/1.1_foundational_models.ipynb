# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = model.invoke("What's the capital of the Moon?")
#       2
#       3 response
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1747, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1745     _handle_openai_bad_request(e)
#    1746 except openai.APIError as e:
# -> 1747     _handle_openai_api_error(e)
#    1748 except Exception as e:
#    1749     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1742, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1735         return _construct_lc_result_from_responses_api(
#    1736             response,
#    1737             schema=original_schema_obj,
#    1738             metadata=generation_info,
#    1739             output_version=self.output_version,
#    1740         )
#    1741     else:
# -> 1742         raw_response = self.client.with_raw_response.create(**payload)
#    1743         response = raw_response.parse()
#    1744 except openai.BadRequestError as e:
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1366     warnings.warn(
#    1367         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1368         "Please pass raw bytes via the `content` parameter instead.",
#    1369         DeprecationWarning,
#    1370         stacklevel=2,
#    1371     )
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1145             err.response.read()
#    1147         log.debug("Re-raising status error")
# -> 1148         raise self._make_status_error_from_response(err.response) from None
#    1150     break
#    1152 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
print(response.content)

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 7
#       3     # Kwargs passed to the model:
#       4     temperature=1.0
#       5 )
#       6
# ----> 7 response = model.invoke("What's the capital of the Moon?")
#       8 print(response.content)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1747, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1745     _handle_openai_bad_request(e)
#    1746 except openai.APIError as e:
# -> 1747     _handle_openai_api_error(e)
#    1748 except Exception as e:
#    1749     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1742, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1735         return _construct_lc_result_from_responses_api(
#    1736             response,
#    1737             schema=original_schema_obj,
#    1738             metadata=generation_info,
#    1739             output_version=self.output_version,
#    1740         )
#    1741     else:
# -> 1742         raw_response = self.client.with_raw_response.create(**payload)
#    1743         response = raw_response.parse()
#    1744 except openai.BadRequestError as e:
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1366     warnings.warn(
#    1367         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1368         "Please pass raw bytes via the `content` parameter instead.",
#    1369         DeprecationWarning,
#    1370         stacklevel=2,
#    1371     )
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/openai/_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1145             err.response.read()
#    1147         log.debug("Re-raising status error")
# -> 1148         raise self._make_status_error_from_response(err.response) from None
#    1150     break
#    1152 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-6")
#       2
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:1947, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1945 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1946 try:
# -> 1947     data = self._create(payload)
#    1948 except anthropic.BadRequestError as e:
#    1949     _handle_anthropic_bad_request(e)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:1577, in ChatAnthropic._create(self, payload)
#    1575 if "betas" in payload:
#    1576     return self._client.beta.messages.create(**payload)
# -> 1577 return self._client.messages.create(**payload)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Downloads/Know/Code/lca-lc-foundations/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}, 'request_id': 'req_011CeVNsZyjDUFxRCGK5wR4s'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, no permanent residents, and no sovereign nations. Under the **Outer Space Treaty of 1967**, to which most spacefaring nations are signatories, no nation can claim sovereignty over the Moon or any other celestial body.\n\nHowever, in science fiction, various lunar cities are often given "capitals." For example:\n\n*   In **Robert A. Heinlein’s *The Moon Is a Harsh Mistress***, the main lunar settlement is **Luna City**.\n*   In **Andy Weir’s *Artemis***, the city is simply called **Artemis**.\n*   In various other works, lunar colonies are sometimes referred to as **Armstrong City** (named after Neil Armstrong) or **Shackleton Base** (located at the Moon’s south pole).\n\nIn reality, the Moon remains an international commons, not a political state.', 'extras': {'signature': 'EnEKbwERTTIPM95108dhFZerrDt2ZsNR+G2xGTlRIiuieuq3zr28FBZYQ0rM4qbBkMdLwyypIUgEyqgn/o6hw0DM+MSJ2ZUX9ZEXAvmLSHu8RIfKjsenGz6e/8CUd+4kaz7dO1i7EaJnep3rCdrKO49oTg=='}}]

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='bbdf96a6-7c76-481f-af6d-3351eb4f79d8'),
#               AIMessage(content=[{'type': 'text', 'text': 'The Moon does not have a capital city, nor does it have any countries, governments, or political divisions. \n\nUnder the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no nation can claim sovereignty over the Moon or any other celestial body. Therefore, the Moon is considered the "province of all mankind" and is not subject to national appropriation.', 'extras': {'signature': 'EnEKbwERTTIPv9aqi5g56mayUNWciqdFLyltD21w9eVyLIaHmnrcV3ru9KL+NJFezrw2avxxHyb+ZfxMJpK/ZOQ8ELEboPhZo0AIs8PkSmRP+yF1HMOUningrzJZB+O/5Drj+qUTa3YxuAp4rAHyNNR4uQ=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a048fc-35ec-7e92-9f0e-aa38f74e0dd5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 84, 'total_tokens': 94, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital city, nor does it have any countries, governments, or political divisions. \n\nUnder the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no nation can claim sovereignty over the Moon or any other celestial body. Therefore, the Moon is considered the "province of all mankind" and is not subject to national appropriation.', 'extras': {'signature': 'EnEKbwERTTIPv9aqi5g56mayUNWciqdFLyltD21w9eVyLIaHmnrcV3ru9KL+NJFezrw2avxxHyb+ZfxMJpK/ZOQ8ELEboPhZo0AIs8PkSmRP+yF1HMOUningrzJZB+O/5Drj+qUTa3YxuAp4rAHyNNR4uQ=='}}]

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='c3da5eb1-79a9-4bd6-b346-839425b13931'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='43dd0a01-ab35-44e5-a5d2-6eed819f9041', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='120184a7-4236-42a0-be30-c705d4d50bb5'),
#               AIMessage(content=[{'type': 'text', 'text': 'It is important to clarify that **Luna City is a fictional location.** While humans have landed on the Moon, there are currently no permanent settlements, cities, or government structures there, and therefore no "capital."\n\nHowever, "Luna City" is one of the most famous tropes in science fiction. Because the Moon has been a primary target for writers for over a century, the name has been used in many different ways:\n\n### 1. The Fictional "Luna City"\nThe most famous literary reference comes from **Robert A. Heinlein’s 1951 novel *The Moon Is a Harsh Mistress***. In the book, Luna City (often referred to simply as "Luna") is a sprawling underground colony built inside the walls of an extinct volcanic crater. It serves as the primary hub for lunar society, housing thousands of people who live, work, and eventually revolt against Earth’s rule.\n\n### 2. Why the Name?\n"Luna" is the Latin word for the Moon. In speculative fiction, naming the capital "Luna City" is a way of establishing that the settlement has become a permanent, civilized extension of Earth rather than just an exploration outpost. It implies a sense of permanence and civic infrastructure—schools, shops, and government—rather than just scientific research labs.\n\n### 3. Real-Life Concepts vs. Fiction\nWhile there is no Luna City today, space agencies like **NASA (through the Artemis program)** and international partners are currently planning the **Lunar Gateway** and the **Artemis Base Camp**. \n*   **The Artemis Base Camp:** This is the current "real-world" equivalent of a lunar city. It is planned to be located near the Moon\'s South Pole because that area receives constant sunlight (for solar power) and has water ice in shadowed craters (for life support and rocket fuel).\n*   **The Problem of Capitals:** In reality, the **Outer Space Treaty of 1967** prevents any nation from claiming sovereignty over the Moon or any celestial body. Because no nation can own the Moon, there can be no legal "capital" in the traditional sense—it remains a "global commons."\n\n### 4. Luna City in Pop Culture\nBecause of its evocative name, the concept of a "Luna City" appears in:\n*   **Video Games:** Games like *Destiny* or *Elite Dangerous* often feature human colonies on the Moon with names derived from "Luna" or "Selene" (the Greek goddess of the Moon).\n*   **Movies and TV:** Many sci-fi shows, such as *Futurama* (which features a popular Luna Park and lunar colonies), lean into the idea that if humans lived on the Moon, the main city would serve as the hub for everything from tourism to mining.\n\n**In summary:** If you are looking for a place to visit, you will have to settle for the moon rocks at a science museum! But if you are looking for a fascinating setting for a story, Luna City is the go-to destination for space-faring fiction.', 'extras': {'signature': 'EnEKbwERTTIPRasiPGVYJcz4ptlM9zHiTk7bw8WQHeidPaoEmLiGQCYnSzYegUMh/+o6pAW94/OCJPgHPDTXBoeW5Rv0EfQeVotrwaBUx8N4xmNX6UsYthvaZFmFz/DRdgraDJNuxXC+D7sSWKr8eUS+lg=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a048fc-9423-7461-9880-cbfef58e2dac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 639, 'total_tokens': 668, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# [{'type': 'text', 'text': 'To', 'index': 0}][{'type': 'text', 'text': ' clear up a common point of confusion: **Luna City does not exist in the real world.**\n\nThere', 'index': 0}][{'type': 'text', 'text': ' is no "capital of the Moon" because the Moon is currently governed by the **Outer Space Treaty of 196', 'index': 0}][{'type': 'text', 'text': '7**, which prohibits any nation from claiming sovereignty over celestial bodies.\n\nHowever, "Luna City" is a titan of', 'index': 0}][{'type': 'text', 'text': ' science fiction literature and a common name used in theoretical space architecture. Here is everything you need to know about the various versions of Luna City.', 'index': 0}][{'type': 'text', 'text': '\n\n---\n\n### 1. The Most Famous Version: *The Moon Is a Harsh Mistress* (1966', 'index': 0}][{'type': 'text', 'text': ')\nThe most iconic "Luna City" comes from Robert A. Heinlein’s classic novel. In this story', 'index': 0}][{'type': 'text', 'text': ', Luna City is a sprawling underground metropolis built into the lunar rock.\n*   **The Setting:** It is a penal', 'index': 0}][{'type': 'text', 'text': ' colony (a "Luna-traz") that has evolved into a self-sustaining society.\n*   **The', 'index': 0}][{'type': 'text', 'text': ' Lifestyle:** Because of the low gravity, the citizens are tall and thin. The city is a labyrinth of tunnels pressurized by massive', 'index': 0}][{'type': 'text', 'text': ' airlocks.\n*   **The Politics:** The city is a hotbed of libertarian revolution, famously governed by the mantra', 'index': 0}][{'type': 'text', 'text': ' **TANSTAAFL** ("There Ain\'t No Such Thing As A Free Lunch"). It is the center of the lunar', 'index': 0}][{'type': 'text', 'text': ' rebellion against Earth’s rule.\n\n### 2. The Pop Culture "Luna City"\nThe name has been used in dozens', 'index': 0}][{'type': 'text', 'text': ' of other settings, appearing as a staple of "Golden Age" sci-fi:\n*   **Luna City (', 'index': 0}][{'type': 'text', 'text': 'Doctor Who):** In the 1960s episodes, Luna City is depicted as a colony that Earth citizens', 'index': 0}][{'type': 'text', 'text': ' visit for holidays or work.\n*   **Science Fiction Tropes:** In almost every depiction, Luna City shares a specific architectural aesthetic: dom', 'index': 0}][{'type': 'text', 'text': 'ed or subterranean structures, pressurized airlocks, hydroponic gardens, and a society that relies heavily on recycling air and water', 'index': 0}][{'type': 'text', 'text': '.\n\n### 3. The "Real" Luna City: Artemis and Lunar Gateway\nWhile there is no capital, NASA and other', 'index': 0}][{'type': 'text', 'text': ' international space agencies are currently working on projects that will eventually resemble a "city."\n*   **The Lunar Gateway:** This', 'index': 0}][{'type': 'text', 'text': ' is the current project by NASA and its partners to build a small space station that will orbit the Moon. It will act', 'index': 0}][{'type': 'text', 'text': ' as a communications hub and a staging point for trips to the lunar surface.\n*   **Artemis Base Camp:**', 'index': 0}][{'type': 'text', 'text': ' NASA plans to establish a permanent human presence at the lunar South Pole. It won’t be a "city" in', 'index': 0}][{'type': 'text', 'text': ' the traditional sense, but it will be a base of operations involving power grids, lunar rovers, and permanent habitat modules', 'index': 0}][{'type': 'text', 'text': '.\n*   **The Shackleton Crater:** If a city were ever built on the Moon, scientists believe it would be here.', 'index': 0}][{'type': 'text', 'text': ' Because the crater is at the South Pole, it experiences "peaks of eternal light" (constant solar power) and is believed', 'index': 0}][{'type': 'text', 'text': ' to have deep ice deposits (water and rocket fuel) in its permanently shadowed regions.\n\n### 4. What would a', 'index': 0}][{'type': 'text', 'text': ' real Luna City look like?\nIf we were to build a true Luna City today, science suggests it would look very different fr ...
