# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunaris Prime.
#
# - Location: tucked into Shackleton Crater’s southern rim, where constant shade meets sunlit rims via giant solar mirrors.
# - Government: The Lunar Synod, a representative council from lunar districts called basins, meets in the Grand Dome.
# - Economy: helium-3, water-ice mining, biotech, and high-value lunar industries.
# - Cityscape: a lattice of glass towers, basalt-block facades, and ringed transit corridors fed by a central power spine; a luminous canopy over the main square is projected by solar mirrors.
# - Culture: aurora-lit festivals, public art in light and shadow, and a strong tradition of scientific exploration fused with lunar poetry.
# - Transportation: gravity-tether elevators, mag-lev trams in a circular belt, and drone/lander hubs at the rim.
#
# If you want, I can tailor Lunaris Prime to a specific era, mood (utopian, dystopian, noir), or level of technological detail.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x7b9f98139fc0>, 'last_modified': datetime.datetime(2026, 9, 4, 8, 54, 59, 24000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s a look at the capital that matches the vision in your image. I’m calling it Caelspire.
#
# Overview
# - Caelspire is the gleaming seat of power for a federation of species on a dry, canyon-carved world. The city sits on a high basalt promontory, where jagged cliffs meet a broad, flat basin. A vast blue planet hangs in the sky behind the skyline, casting a cool, otherworldly light over crystalline towers and glassy walkways. The ground glows with faint azure rings—energy conduits humming to power the city above.
#
# Cityscape and districts
# - Skyline: The heart of Caelspire is a vertical forest of spires—tall, slender towers made of solicrystal and glass that refract starlight into shifting blues. Some spires are capped with balcony gardens; others terminate in glass domes that act as weatherbreakers and data hubs.
# - The Aegis Dome: A translucent canopy that covers the administrative district, containing the seat of government and the Archive of Echoes, where memories and records are stored in memory-glass orbs.
# - The Spirebelt: A constellation of shorter towers that house residences, markets, schools, and clinics. It’s the city’s living room—where people meet, talk, and trade.
# - Foundry Cliffs: A rugged sector carved into the canyon walls where drones, machines, and craftspeople labor to maintain gravity lifts, energy lattices, and transit corridors.
# - Cultural quarter: A crescent of amphitheaters, lantern-lit corridors, and a Library of Echoes where voices—chants, stories, and songs—are digitized and stored for future generations.
# - The Moonwell: A circular plaza fed by a quiet blue pool of energy. It’s both a public gathering place and a source of purified water distilled from atmospheric humidity.
#
# Governance and society
# - Ruling body: The Council of Nine, representing nine major sectors (science, defense, trade, culture, agriculture, diplomacy, youth, elders, and migrants). A primarch—an elected leader who lives atop a levitating pavilion—guides council decisions and ceremonial duties.
# - Law and life: Caelspire emphasizes transparency and consensus, with a strong respect for memory and history. Public life blends ritual with science: annual festivals celebrate celestial alignments, and town meetings are broadcast through light-forms that project thoughts as shimmering phrases.
# - Population: A diverse mix of species tuned to the world’s peculiar light and gravity. Many residents have reflective eyes or skin that shifts color with mood; others wear neural-linked garments that adjust temperature and mood lighting automatically.
#
# Technology and transport
# - Energy: The city is powered by a lattice of crystalline nodes drawing nano-fuel from both solar harvest and deep crustal vents. The blue glow on the ground is an energy-artifact deposit, a visible sign of a city living off its own energy memory.
# - Transit: Gravity lifts, magnetic sky-rails, and sky-barges weave through canyons and above streets. Personal flight bands and hover-taxis are common for reaching distant districts.
# - Architecture: Materials are lightweight yet resilient, combining Solaris-crystal, glass, and basalt composites. Buildings are designed to breathe—air exchange and passive cooling are built into facades.
# - Communications: Aether-net spires link Caelspire to other cities. The Library of Echoes stores not just data but voices and intents, inscribed into memory glass and spoken again on request.
#
# Culture and daily life
# - Arts and language: Light-sculpting performances, where dancers bend beams of light to tell stories. A visual language—GleamScript—translates gestures and light patterns into poetry and news.
# - Food and water: A cadre of vertical farms supplies fresh greens; water is conserved with clever condensation and atmospheric distillation. The Moonwell provides a gentle daily supply of purified energy-water used for cooking and rituals.
# - Rituals: The Festival of Helio-Glass celebrates the city’s resilience in a world with irregular weather and long nights. Citizens wear crystal masks that modulate voice and resonance, lending a choir-like quality to public discourse.
#
# History and current events
# - Founding myth: Caelspire grew when the Anvil Crags were stabilized by a collaboration of engineers, mystics, and migrants. The great Aegis Dome was erected to shield the city from violent weather while letting the wind carry ideas as sound and light.
# - Challenges: Water scarcity and energy management are ongoing concerns, especially during long nights when solar input dips. Tensions simmer with a neighboring city-state that covets Caelspire’s energy memory. There are also external threats from asteroid fragments and rogue drones that drift through the canyons.
# - Recent turning point: The Council’s decision to unlock the Moonwell’s deeper energies allowed Caelspire to wean off a fossil-fuel phase and invest in a more resilient, renewable grid. This has sparked a cultural renaissance—festivals, science fairs, and memory-arts flourish.
#
# Landmarks and notable sites
# - The Great Aegis Dome: Government, archives, and ceremonial center wrapped in a shimmering shield.
# - The Lattice Bridge: A sky-connecting glass arch linking central spires to the Moonwell plaza.
# - The Spire of Whispers: The primary communications tower, where messages arrive as auroral streams.
# - The Library of Echoes: A vault of memory glass and voice-recording vaults stored in the ceiling like constellations.
# - The Dawn Gardens: Terrace gardens that glow softly at sunrise, a place of quiet contemplation.
#
# If you’d like, I can tailor Caelspire to a different vibe—more utopian, more militaristic, more desert-wardy, or more sea-adjacent. I can also rename the capital, adjust its tech level, or introduce key figures (Primarch, council members, legendary architects) to fit your story. Want a short scene set here, perhaps a meeting in the Aegis Dome or a festival night at the Moonwell?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import sounddevice as sd
#       2 from scipy.io.wavfile import write
#       3 import base64
#       4 import io
#
# File ~/venv/lib/python3.12/site-packages/sounddevice.py:73
#      71             break
#      72     else:
# ---> 73         raise OSError('PortAudio library not found')
#      74     _lib: ... = _ffi.dlopen(_libname)
#      75 except OSError:
#
# OSError: PortAudio library not found

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
