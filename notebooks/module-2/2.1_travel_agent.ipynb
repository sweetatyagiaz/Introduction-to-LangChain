# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='f7e66dda-848e-4cf4-b9ba-3168e8eec781'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 704, 'prompt_tokens': 2813, 'total_tokens': 3517, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EKMOqcRd1A4nzudcRxDxMzCtjFLPd', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a06c2e-59e6-76b0-8d9e-9c13881aef07-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2027', 'departureDateFlexDays': 0, 'returnDate': None, 'adults': 1, 'max_sector_stopovers': 0}, 'id': 'call_TTwoHB7geUMjrCU4OPVz4Mks', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2813, 'output_tokens': 704, 'total_tokens': 3517, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "San Francisco → Tokyo on 31/03/2027, 1 adult [≤0 stops/sector]",\n  "currency": "EUR",\n  "passengers": {\n    "adults": 1,\n    "children": 0,\n    "infants": 0\n  },\n  "resultsCount": 11,\n  "itineraries": [\n    {\n      "id": "0f9c188451ac0000526d253d_0|0f9c188451ac0000526d253d_1",\n      "price": 405.0,\n      "priceFormatted": "405 EUR",\n      "totalDurationSeconds": 39900,\n      "bookingUrl": "https://kiwi.com/u/7wtc5r8",\n      "imageId": "tokyo_jp",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 0,\n        "checkedBag": 0\n      },\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2027-03-31T12:20:00",\n        "arrivalTime": "2027-04-01T15:25:00",\n        "durationSeconds": 39900,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "fromName": "San Francisco International",\n            "toName": "Narita International",\n            "fromCountry": "United States",\n            "toCountry": "Japan",\n            "departureTime": "2027-03-31T12:20:00",\n            "arrivalTime": "2027-04-01T15:25:00",\n            "durationSeconds": 39900,\n            "carrier": "NH",\n            "carrierName": "All Nippon Airways",\n            "flightNumber": "NH7",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c0ecd51ac000028b03522_0|0f9c0ecd51ac000028b03522_1",\n      "price": 1053.0,\n      "priceFormatted": "1053 EUR",\n      "totalDurationSeconds": 40500,\n      "bookingUrl": "https://kiwi.com/u/m5k2bw",\n      "imageId": "tokyo_jp",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 0,\n        "checkedBag": 0\n      },\n      "outbound": {\n        "from": "SFO",\n        "to": "HND",\n        "departureTime": "2027-03-31T01:45:00",\n        "arrivalTime": "2027-04-01T05:00:00",\n        "durationSeconds": 40500,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "HND"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "HND",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "fromName": "San Francisco International",\n            "toName": "Haneda",\n            "fromCountry": "United States",\n            "toCountry": "Japan",\n            "departureTime": "2027-03-31T01:45:00",\n            "arrivalTime": "2027-04-01T05:00:00",\n            "durationSeconds": 40500,\n            "carrier": "NH",\n            "carrierName": "All Nippon Airways",\n            "flightNumber": "NH107",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c209f51ac00003f3a153d_0",\n      "price": 1184.0,\n      "priceFormatted": "1184 EUR",\n      "totalDurationSeconds": 40800,\n      "bookingUrl": "https://kiwi.com/u/jxs44w",\n      "imageId": "tokyo_jp",\n      "baggage": {\n        "personalItem": 1,\n        "cabinBag": 0,\n        "checkedBag": 1\n      },\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2027-03-31T11:40:00",\n        "arrivalTime": "2027-04-01T15:00:00",\n        "durationSeconds": 40800,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "fromName": "San Francisco International",\n            "toName": "Narita International",\n            "fromCou ...
#               AIMessage(content='Here are direct (non-stop) outbound options from San Francisco (SFO) to Tokyo on March 31, 2027. All are one-way, Economy, and have zero stops.\n\n| Route | Times (Outbound) | Cabin | Price | Booking |\n|---|---|---|---:|---|\n| SFO → NRT | 31 Mar 12:20 → 01 Apr 15:25 (11h 05m) | Economy | 405 EUR | https://kiwi.com/u/7wtc5r8 |\n| SFO → HND | 31 Mar 01:45 → 01 Apr 05:00 (11h 15m) | Economy | 1053 EUR | https://kiwi.com/u/m5k2bw |\n| SFO → NRT | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1184 EUR | https://kiwi.com/u/jxs44w |\n| SFO → NRT | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1191 EUR | https://kiwi.com/u/njgc5x |\n| SFO → NRT | 31 Mar 12:20 → 01 Apr 15:25 (11h 05m) | Economy | 1200 EUR | https://kiwi.com/u/v2dwzb |\n| SFO → NRT | 31 Mar 12:20 → 01 Apr 15:25 (11h 05m) | Economy | 1207 EUR | https://kiwi.com/u/fr2q2s |\n| SFO → HND | 31 Mar 10:25 → 01 Apr 13:55 (11h 30m) | Economy | 1230 EUR | https://kiwi.com/u/mtgmm6 |\n| SFO → HND | 31 Mar 10:25 → 01 Apr 13:55 (11h 30m) | Economy | 1237 EUR | https://kiwi.com/u/h48csd |\n| SFO → HND | 31 Mar 01:45 → 01 Apr 05:00 (11h 15m) | Economy | 1253 EUR | https://kiwi.com/u/3ts7dz |\n\nBest price: 405 EUR with NH7 SFO → NRT (12:20 on Mar 31 → 15:25 on Apr 1).\n\nShortest duration (same as best price): 11h 05m for the NH7 SFO → NRT option.\n\nRecommendation: If you want the lowest price, choose NH7 SFO → NRT. If you’d prefer Haneda instead of Narita, the 11h15m options on NH107 or similar are solid, though they’re pricier.\n\nHave a great trip! Fun fact: Tokyo has the most Michelin-starred restaurants of any city in the world, making it a top foodie destination.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5770, 'prompt_tokens': 7395, 'total_tokens': 13165, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 5120, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 2688, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EKMP1V4LfWSD4tyDdmaBaroBf5aXH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a06c2e-84f6-7e63-8a55-edf04830fb35-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7395, 'output_tokens': 5770, 'total_tokens': 13165, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 5120}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct (non-stop) outbound options from San Francisco (SFO) to Tokyo on March 31, 2027. All are one-way, Economy, and have zero stops.
#
# | Route | Times (Outbound) | Cabin | Price | Booking |
# |---|---|---|---:|---|
# | SFO → NRT | 31 Mar 12:20 → 01 Apr 15:25 (11h 05m) | Economy | 405 EUR | https://kiwi.com/u/7wtc5r8 |
# | SFO → HND | 31 Mar 01:45 → 01 Apr 05:00 (11h 15m) | Economy | 1053 EUR | https://kiwi.com/u/m5k2bw |
# | SFO → NRT | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1184 EUR | https://kiwi.com/u/jxs44w |
# | SFO → NRT | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1191 EUR | https://kiwi.com/u/njgc5x |
# | SFO → NRT | 31 Mar 12:20 → 01 Apr 15:25 (11h 05m) | Economy | 1200 EUR | https://kiwi.com/u/v2dwzb |
# | SFO → NRT | 31 Mar 12:20 → 01 Apr 15:25 (11h 05m) | Economy | 1207 EUR | https://kiwi.com/u/fr2q2s |
# | SFO → HND | 31 Mar 10:25 → 01 Apr 13:55 (11h 30m) | Economy | 1230 EUR | https://kiwi.com/u/mtgmm6 |
# | SFO → HND | 31 Mar 10:25 → 01 Apr 13:55 (11h 30m) | Economy | 1237 EUR | https://kiwi.com/u/h48csd |
# | SFO → HND | 31 Mar 01:45 → 01 Apr 05:00 (11h 15m) | Economy | 1253 EUR | https://kiwi.com/u/3ts7dz |
#
# Best price: 405 EUR with NH7 SFO → NRT (12:20 on Mar 31 → 15:25 on Apr 1).
#
# Shortest duration (same as best price): 11h 05m for the NH7 SFO → NRT option.
#
# Recommendation: If you want the lowest price, choose NH7 SFO → NRT. If you’d prefer Haneda instead of Narita, the 11h15m options on NH107 or similar are solid, though they’re pricier.
#
# Have a great trip! Fun fact: Tokyo has the most Michelin-starred restaurants of any city in the world, making it a top foodie destination.
